# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 10))

# t1-t9的概念任务数据
concept_data = {
    't1': [0.9686, 0.6667, 0.6435, 0.6961, 0.7214, 0.6708, 0.7024, 0.739, 0.7203],
    't2': [None, 0.9877, 0.7566, 0.7443, 0.7568, 0.632, 0.7014, 0.7463, 0.6843],
    't3': [None, None, 0.9827, 0.6578, 0.6913, 0.6892, 0.6467, 0.7126, 0.6836],
    't4': [None, None, None, 0.9388, 0.7809, 0.631, 0.6785, 0.7851, 0.6851],
    't5': [None, None, None, None, 0.9756, 0.6864, 0.6956, 0.7437, 0.7362],
    't6': [None, None, None, None, None, 0.9953, 0.6833, 0.718, 0.7303],
    't7': [None, None, None, None, None, None, 0.9667, 0.7062, 0.6693],
    't8': [None, None, None, None, None, None, None, 0.9443, 0.6904],
    't9': [None, None, None, None, None, None, None, None, 0.9829]
}

# t1-t9的分类任务数据
class_data = {
    't1': [0.9239, 0, 0, 0, 0, 0, 0, 0, 0],
    't2': [None, 0.9888, 0, 0, 0, 0, 0, 0, 0],
    't3': [None, None, 0.9925, 0, 0, 0, 0, 0, 0],
    't4': [None, None, None, 0.9469, 0, 0, 0, 0, 0],
    't5': [None, None, None, None, 0.9688, 0, 0, 0, 0],
    't6': [None, None, None, None, None, 0.9917, 0, 0, 0],
    't7': [None, None, None, None, None, None, 0.9526, 0, 0],
    't8': [None, None, None, None, None, None, None, 0.9779, 0],
    't9': [None, None, None, None, None, None, None, None, 0.9748]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-AwA-phase_9')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
plt.savefig('Baseline-AwA-phase_9.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 10))

# t1-t9的概念任务数据
concept_data = {
    't1': [0.7494, 0.663, 0.65, 0.6613, 0.687, 0.6558, 0.6511, 0.702, 0.6723],
    't2': [None, 0.6502, 0.6349, 0.6414, 0.6747, 0.6478, 0.6491, 0.6845, 0.6641],
    't3': [None, None, 0.6093, 0.5921, 0.6029, 0.6016, 0.6306, 0.6327, 0.6316],
    't4': [None, None, None, 0.6245, 0.6309, 0.6241, 0.6378, 0.646, 0.6399],
    't5': [None, None, None, None, 0.669, 0.6263, 0.6441, 0.6727, 0.6663],
    't6': [None, None, None, None, None, 0.6278, 0.6147, 0.6706, 0.6591],
    't7': [None, None, None, None, None, None, 0.6173, 0.6627, 0.6468],
    't8': [None, None, None, None, None, None, None, 0.6578, 0.6457],
    't9': [None, None, None, None, None, None, None, None, 0.6134]
}

# t1-t9的分类任务数据
class_data = {
    't1': [0.81, 0, 0, 0, 0, 0, 0, 0, 0],
    't2': [None, 0.882, 0, 0, 0, 0, 0, 0, 0],
    't3': [None, None, 0.712, 0, 0, 0, 0, 0, 0],
    't4': [None, None, None, 0.8306, 0, 0, 0, 0, 0],
    't5': [None, None, None, None, 0.7423, 0, 0, 0, 0],
    't6': [None, None, None, None, None, 0.8649, 0, 0, 0],
    't7': [None, None, None, None, None, None, 0.8475, 0, 0],
    't8': [None, None, None, None, None, None, None, 0.875, 0],
    't9': [None, None, None, None, None, None, None, None, 0.8458]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-CUB-phase_9')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-CUB-phase_9.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 9))

# t1-t8的概念任务数据
concept_data = {
    't1': [0.9686, 0.6957, 0.6703, 0.6774, 0.7316, 0.7189, 0.7061, 0.7281],
    't2': [None, 0.9853, 0.7384, 0.6723, 0.7342, 0.7191, 0.715, 0.7052],
    't3': [None, None, 0.981, 0.651, 0.6953, 0.7033, 0.7101, 0.7113],
    't4': [None, None, None, 0.8253, 0.6614, 0.6337, 0.7824, 0.6827],
    't5': [None, None, None, None, 0.9909, 0.768, 0.7089, 0.7333],
    't6': [None, None, None, None, None, 0.9762, 0.7158, 0.7477],
    't7': [None, None, None, None, None, None, 0.9683, 0.656],
    't8': [None, None, None, None, None, None, None, 0.9759]
}

# t1-t8的分类任务数据
class_data = {
    't1': [0.9239, 0, 0, 0, 0, 0, 0, 0],
    't2': [None, 0.9925, 0, 0, 0, 0, 0, 0],
    't3': [None, None, 0.9828, 0, 0, 0, 0, 0],
    't4': [None, None, None, 0.9096, 0, 0, 0, 0],
    't5': [None, None, None, None, 0.9865, 0, 0, 0],
    't6': [None, None, None, None, None, 0.9576, 0, 0],
    't7': [None, None, None, None, None, None, 0.9723, 0],
    't8': [None, None, None, None, None, None, None, 0.9728]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-AwA-phase_8')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-AwA-phase_8.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 9))

# t1-t8的概念任务数据
concept_data = {
    't1': [0.7495, 0.6604, 0.693, 0.7212, 0.7178, 0.6373, 0.7063, 0.6937],
    't2': [None, 0.6321, 0.6783, 0.6993, 0.6976, 0.6359, 0.6949, 0.6818],
    't3': [None, None, 0.6328, 0.6416, 0.6154, 0.5871, 0.6883, 0.688],
    't4': [None, None, None, 0.6718, 0.688, 0.6308, 0.6963, 0.6967],
    't5': [None, None, None, None, 0.657, 0.6201, 0.645, 0.684],
    't6': [None, None, None, None, None, 0.6307, 0, 0.6788],
    't7': [None, None, None, None, None, None, 0.8623, 0.6832],
    't8': [None, None, None, None, None, None, None, 0.646]
}

# t1-t8的分类任务数据
class_data = {
    't1': [0.8101, 0, 0, 0, 0, 0, 0, 0],
    't2': [None, 0.8843, 0, 0, 0, 0, 0, 0],
    't3': [None, None, 0.7928, 0, 0, 0, 0, 0],
    't4': [None, None, None, 0.8663, 0, 0, 0, 0],
    't5': [None, None, None, None, 0.7626, 0, 0.6579, 0],
    't6': [None, None, None, None, None, 0.9063, 0.6417, 0],
    't7': [None, None, None, None, None, None, 0, 0],
    't8': [None, None, None, None, None, None, None, 0.8861]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-CUB-phase_8')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-CUB-phase_8.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 8))

# t1-t7的概念任务数据
concept_data = {
    't1': [0.9686, 0.656, 0.6929, 0.7292, 0.6791, 0.7226, 0.7473],
    't2': [None, 0.9846, 0.6906, 0.7617, 0.6403, 0.7366, 0.7237],
    't3': [None, None, 0.9684, 0.694, 0.6978, 0.6831, 0.741],
    't4': [None, None, None, 0.9509, 0.6957, 0.7213, 0.7399],
    't5': [None, None, None, None, 0.9927, 0.7039, 0.7064],
    't6': [None, None, None, None, None, 0.9658, 0.7066],
    't7': [None, None, None, None, None, None, 0.9723]
}

# t1-t7的分类任务数据
class_data = {
    't1': [0.9239, 0, 0, 0, 0, 0, 0],
    't2': [None, 0.9644, 0, 0, 0, 0, 0],
    't3': [None, None, 0.9803, 0, 0, 0, 0],
    't4': [None, None, None, 0.9571, 0, 0, 0],
    't5': [None, None, None, None, 0.9821, 0, 0],
    't6': [None, None, None, None, None, 0.9634, 0],
    't7': [None, None, None, None, None, None, 0.9594]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-AwA-phase_7')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-AwA-phase_7.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 8))

# t1-t7的概念任务数据
concept_data = {
    't1': [0.7495, 0.6688, 0.6599, 0.7123, 0.6945, 0.6504, 0.7254],
    't2': [None, 0.6384, 0.6379, 0.695, 0.6795, 0.6426, 0.717],
    't3': [None, None, 0.6134, 0.6527, 0.6447, 0.6223, 0.6954],
    't4': [None, None, None, 0.6969, 0.6848, 0.6283, 0.7059],
    't5': [None, None, None, None, 0.6413, 0.628, 0.6861],
    't6': [None, None, None, None, None, 0.6338, 0.6739],
    't7': [None, None, None, None, None, None, 0.6524]
}

# t1-t7的分类任务数据
class_data = {
    't1': [0.8101, 0, 0, 0, 0, 0, 0],
    't2': [None, 0.8795, 0, 0, 0, 0, 0],
    't3': [None, None, 0.7549, 0, 0, 0, 0],
    't4': [None, None, None, 0.7717, 0, 0, 0],
    't5': [None, None, None, None, 0.8887, 0, 0],
    't6': [None, None, None, None, None, 0.8625, 0],
    't7': [None, None, None, None, None, None, 0.8878]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-CUB-phase_7')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-CUB-phase_7.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 7))

# t1-t6的概念任务数据
concept_data = {
    't1': [0.9686, 0.6516, 0.715, 0.7098, 0.7191, 0.7526],
    't2': [None, 0.9736, 0.7231, 0.6842, 0.7262, 0.709],
    't3': [None, None, 0.965, 0.7218, 0.7036, 0.7534],
    't4': [None, None, None, 0.9909, 0.7245, 0.7429],
    't5': [None, None, None, None, 0.9709, 0.7116],
    't6': [None, None, None, None, None, 0.9753]
}

# t1-t6的分类任务数据
class_data = {
    't1': [0.9239, 0, 0, 0, 0, 0],
    't2': [None, 0.9508, 0, 0, 0, 0],
    't3': [None, None, 0.9599, 0, 0, 0],
    't4': [None, None, None, 0.9825, 0, 0],
    't5': [None, None, None, None, 0.9626, 0],
    't6': [None, None, None, None, None, 0.9644]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-AwA-phase_6')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-AwA-phase_6.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 7))

# t1-t6的概念任务数据
concept_data = {
    't1': [0.7494, 0.6819, 0.7, 0.6994, 0.7225, 0.694],
    't2': [None, 0.6346, 0.6798, 0.6759, 0.677, 0.6549],
    't3': [None, None, 0.6688, 0.6666, 0.663, 0.6609],
    't4': [None, None, None, 0.6697, 0.6767, 0.6587],
    't5': [None, None, None, None, 0.6782, 0.6558],
    't6': [None, None, None, None, None, 0.6377]
}

# t1-t6的分类任务数据
class_data = {
    't1': [0.8101, 0, 0, 0, 0, 0],
    't2': [None, 0.8286, 0, 0, 0, 0],
    't3': [None, None, 0.8278, 0, 0, 0],
    't4': [None, None, None, 0.7924, 0, 0],
    't5': [None, None, None, None, 0.8682, 0],
    't6': [None, None, None, None, None, 0.8741]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-CUB-phase_6')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-CUB-phase_6.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 6))

# t1-t5的概念任务数据
concept_data = {
    't1': [0.9686, 0.6822, 0.7379, 0.7301, 0.7512],
    't2': [None, 0.9848, 0.7159, 0.6956, 0.7485],
    't3': [None, None, 0.9674, 0.7113, 0.7716],
    't4': [None, None, None, 0.9853, 0.7187],
    't5': [None, None, None, None, 0.972]
}

# t1-t5的分类任务数据
class_data = {
    't1': [0.9239, 0, 0, 0, 0],
    't2': [None, 0.9679, 0, 0, 0],
    't3': [None, None, 0.9399, 0, 0],
    't4': [None, None, None, 0.976, 0],
    't5': [None, None, None, None, 0.9694]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-AwA-phase_5')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-AwA-phase_5.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 6))

# t1-t5的概念任务数据
concept_data = {
    't1': [0.7494, 0.7163, 0.724, 0.6942, 0.7361],
    't2': [None, 0.666, 0.681, 0.6506, 0.7086],
    't3': [None, None, 0.6886, 0.6686, 0.7024],
    't4': [None, None, None, 0.6538, 0.6975],
    't5': [None, None, None, None, 0.6811]
}

# t1-t5的分类任务数据
class_data = {
    't1': [0.8101, 0, 0, 0, 0],
    't2': [None, 0.8137, 0, 0, 0],
    't3': [None, None, 0.7888, 0, 0],
    't4': [None, None, None, 0.8544, 0],
    't5': [None, None, None, None, 0.8922]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-CUB-phase_5')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-CUB-phase_5.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 5))

# t1-t4的概念任务数据
concept_data = {
    't1': [0.9686, 0.7062, 0.7207, 0.7414],
    't2': [None, 0.9778, 0.7215, 0.7279],
    't3': [None, None, 0.9815, 0.7213],
    't4': [None, None, None, 0.9715]
}

# t1-t4的分类任务数据
class_data = {
    't1': [0.9239, 0, 0, 0],
    't2': [None, 0.9622, 0, 0],
    't3': [None, None, 0.9648, 0],
    't4': [None, None, None, 0.9581]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-AwA-phase_4')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-AwA-phase_4.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 5))

# t1-t4的概念任务数据
concept_data = {
    't1': [0.7495, 0.7217, 0.7383, 0.7698],
    't2': [None, 0.6625, 0.6934, 0.7084],
    't3': [None, None, 0.6977, 0.7138],
    't4': [None, None, None, 0.6782]
}

# t1-t4的分类任务数据
class_data = {
    't1': [0.8101, 0, 0, 0],
    't2': [None, 0.7694, 0, 0],
    't3': [None, None, 0.8297, 0],
    't4': [None, None, None, 0.8741]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-CUB-phase_4')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-CUB-phase_4.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 4))

# t1-t3的概念任务数据
concept_data = {
    't1': [0.9686, 0.7305, 0.7466],
    't2': [None, 0.9677, 0.7425],
    't3': [None, None, 0.9755]
}

# t1-t3的分类任务数据
class_data = {
    't1': [0.9239, 0, 0],
    't2': [None, 0.9307, 0],
    't3': [None, None, 0.9626]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-AwA-phase_3')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-AwA-phase_3.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 4))

# t1-t3的概念任务数据
concept_data = {
    't1': [0.7495, 0.7645, 0.7969],
    't2': [None, 0.6987, 0.7443],
    't3': [None, None, 0.7127]
}

# t1-t3的分类任务数据
class_data = {
    't1': [0.8101, 0, 0],
    't2': [None, 0.7743, 0],
    't3': [None, None, 0.8576]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-CUB-phase_3')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-CUB-phase_3.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 3))

# t1-t2的概念任务数据
concept_data = {
    't1': [0.9686, 0.7528],
    't2': [None, 0.9655]
}

# t1-t2的分类任务数据
class_data = {
    't1': [0.9239, 0],
    't2': [None, 0.9308]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-AwA-phase_2')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-AwA-phase_2.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 3))

# t1-t2的概念任务数据
concept_data = {
    't1': [0.7495, 0.7984],
    't2': [None, 0.7117]
}

# t1-t2的分类任务数据
class_data = {
    't1': [0.8101, 0],
    't2': [None, 0.8181]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(stages, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(stages, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('Baseline-CUB-phase_2')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(stages)
# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('Baseline-CUB-phase_2.png', dpi=300)

# 显示图形
plt.show()
