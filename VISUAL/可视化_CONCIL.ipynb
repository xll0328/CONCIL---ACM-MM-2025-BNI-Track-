# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 3))

# t1-t2的概念任务数据
concept_data = {
    't1': [0.8306, 0.8314],
    't2': [None, 0.801]
}

# t1-t2的分类任务数据
class_data = {
    't1': [0.6927, 0.5688],
    't2': [None, 0.5608]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-CUB-phase_2')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-CUB-phase_2.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 4))

# t1-t3的概念任务数据
concept_data = {
    't1': [0.8306, 0.8309, 0.8312],
    't2': [None, 0.7963, 0.7971],
    't3': [None, None, 0.8054]
}

# t1-t3的分类任务数据
class_data = {
    't1': [0.6927, 0.6253, 0.5803],
    't2': [None, 0.5451, 0.513],
    't3': [None, None, 0.6226]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-CUB-phase_3')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)


# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)
# 保存图表为 PNG 文件
plt.savefig('CONCIL-CUB-phase_3.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 5))

# t1-t4的概念任务数据
concept_data = {
    't1': [0.8306, 0.8309, 0.831, 0.8312],
    't2': [None, 0.7734, 0.7735, 0.7744],
    't3': [None, None, 0.8178, 0.8196],
    't4': [None, None, None, 0.8089]
}

# t1-t4的分类任务数据
class_data = {
    't1': [0.6927, 0.6435, 0.6044, 0.5688],
    't2': [None, 0.5472, 0.5052, 0.4644],
    't3': [None, None, 0.6544, 0.5497],
    't4': [None, None, None, 0.6264]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('持续学习任务的多任务曲线可视化')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('multi_task_curves.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 6))

# t1-t5的概念任务数据
concept_data = {
    't1': [0.8306, 0.8307, 0.831, 0.8312, 0.8311],
    't2': [None, 0.7802, 0.7814, 0.7816, 0.7821],
    't3': [None, None, 0.8115, 0.8113, 0.8115],
    't4': [None, None, None, 0.8011, 0.8018],
    't5': [None, None, None, None, 0.809]
}

# t1-t5的分类任务数据
class_data = {
    't1': [0.6927, 0.6512, 0.6198, 0.595, 0.574],
    't2': [None, 0.6022, 0.5028, 0.4958, 0.4692],
    't3': [None, None, 0.5655, 0.5374, 0.5147],
    't4': [None, None, None, 0.6299, 0.4857],
    't5': [None, None, None, None, 0.6862]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-CUB-phase_5')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-CUB-phase_5.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 7))

# t1-t6的概念任务数据
concept_data = {
    't1': [0.8306, 0.8306, 0.8308, 0.8309, 0.8312, 0.8313],
    't2': [None, 0.7869, 0.7879, 0.7872, 0.7881, 0.7882],
    't3': [None, None, 0.7874, 0.7877, 0.811, 0.7881],
    't4': [None, None, None, 0.8099, 0.8131, 0.8122],
    't5': [None, None, None, None, 0.8172, 0.8142],
    't6': [None, None, None, None, None, 0.8026]
}

# t1-t6的分类任务数据
class_data = {
    't1': [0.6927, 0.6536, 0.6292, 0.6054, 0.5946, 0.58],
    't2': [None, 0.6643, 0.5477, 0.5124, 0.5, 0.4594],
    't3': [None, None, 0.5251, 0.4933, 0.5478, 0.4983],
    't4': [None, None, None, 0.6229, 0.5743, 0.4932],
    't5': [None, None, None, None, 0.5663, 0.4932],
    't6': [None, None, None, None, None, 0.7177]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-CUB-phase_6')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-CUB-phase_6.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 8))

# t1-t7的概念任务数据
concept_data = {
    't1': [0.8306, 0.8308, 0.8308, 0.831, 0.8311, 0.8313, 0.8312],
    't2': [None, 0.7952, 0.7971, 0.7963, 0.7965, 0.7966, 0.7972],
    't3': [None, None, 0.7524, 0.7528, 0.7528, 0.7539, 0.7533],
    't4': [None, None, None, 0.8375, 0.8376, 0.8379, 0.8379],
    't5': [None, None, None, None, 0.7953, 0.7985, 0.7981],
    't6': [None, None, None, None, None, 0.8142, 0.8157],
    't7': [None, None, None, None, None, None, 0.8007]
}

# t1-t7的分类任务数据
class_data = {
    't1': [0.6927, 0.6631, 0.6411, 0.6278, 0.6044, 0.596, 0.5743],
    't2': [None, 0.6808, 0.5513, 0.5335, 0.4911, 0.4888, 0.4464],
    't3': [None, None, 0.5, 0.4901, 0.4743, 0.4624, 0.4387],
    't4': [None, None, None, 0.6043, 0.5886, 0.5807, 0.5551],
    't5': [None, None, None, None, 0.7152, 0.5546, 0.5225],
    't6': [None, None, None, None, None, 0.5936, 0.5239],
    't7': [None, None, None, None, None, None, 0.7295]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-CUB-phase_7')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-CUB-phase_7.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 9))

# t1-t8的概念任务数据
concept_data = {
    't1': [0.8306, 0.8308, 0.8307, 0.8309, 0.8309, 0.8311, 0.8311, 0.831],
    't2': [None, 0.8008, 0.8013, 0.8013, 0.8005, 0.8017, 0.8009, 0.8017],
    't3': [None, None, 0.7516, 0.7527, 0.7524, 0.7528, 0.7537, 0.7544],
    't4': [None, None, None, 0.8158, 0.8164, 0.8161, 0.8159, 0.817],
    't5': [None, None, None, None, 0.8115, 0.8124, 0.8132, 0.8129],
    't6': [None, None, None, None, None, 0.8025, 0.8031, 0.803],
    't7': [None, None, None, None, None, None, 0.8128, 0.8134],
    't8': [None, None, None, None, None, None, None, 0.8031]
}

# t1-t8的分类任务数据
class_data = {
    't1': [0.6927, 0.6683, 0.6512, 0.6393, 0.6205, 0.6023, 0.5873, 0.5751],
    't2': [None, 0.6992, 0.6247, 0.5938, 0.5733, 0.5501, 0.5604, 0.5296],
    't3': [None, None, 0.5181, 0.441, 0.4145, 0.4145, 0.3904, 0.359],
    't4': [None, None, None, 0.5919, 0.5107, 0.5107, 0.5012, 0.5036],
    't5': [None, None, None, None, 0.5868, 0.5114, 0.4475, 0.4384],
    't6': [None, None, None, None, None, 0.7428, 0.5505, 0.512],
    't7': [None, None, None, None, None, None, 0.57, 0.5435],
    't8': [None, None, None, None, None, None, None, 0.7175]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-CUB-phase_8')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-CUB-phase_8.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 10))

# t1-t9的概念任务数据
concept_data = {
    't1': [0.8306, 0.8307, 0.8309, 0.8309, 0.8309, 0.8309, 0.831, 0.831, 0.8312],
    't2': [None, 0.8083, 0.8089, 0.8082, 0.8078, 0.8085, 0.8093, 0.81, 0.8103],
    't3': [None, None, 0.7554, 0.7571, 0.7567, 0.7569, 0.7568, 0.757, 0.758],
    't4': [None, None, None, 0.7772, 0.7762, 0.7771, 0.7775, 0.7777, 0.7776],
    't5': [None, None, None, None, 0.8429, 0.8431, 0.8433, 0.8433, 0.8435],
    't6': [None, None, None, None, None, 0.7991, 0.8018, 0.802, 0.8018],
    't7': [None, None, None, None, None, None, 0.8003, 0.8009, 0.8009],
    't8': [None, None, None, None, None, None, None, 0.8176, 0.8187],
    't9': [None, None, None, None, None, None, None, None, 0.8001]
}

# t1-t9的分类任务数据
class_data = {
    't1': [0.6927, 0.6714, 0.6529, 0.6386, 0.6264, 0.6051, 0.5943, 0.5841, 0.5761],
    't2': [None, 0.6785, 0.646, 0.6106, 0.587, 0.5664, 0.5516, 0.5752, 0.5192],
    't3': [None, None, 0.544, 0.3973, 0.3867, 0.4, 0.384, 0.3467, 0.336],
    't4': [None, None, None, 0.475, 0.4889, 0.4639, 0.4361, 0.4278, 0.4333],
    't5': [None, None, None, None, 0.6134, 0.6082, 0.5954, 0.5902, 0.5825],
    't6': [None, None, None, None, None, 0.6782, 0.5373, 0.4741, 0.4626],
    't7': [None, None, None, None, None, None, 0.6434, 0.4884, 0.4574],
    't8': [None, None, None, None, None, None, None, 0.6977, 0.6686],
    't9': [None, None, None, None, None, None, None, None, 0.7249]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-CUB-phase_9')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-CUB-phase_9.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 11))

# t1-t10的概念任务数据
concept_data = {
    't1': [0.8306, 0.8307, 0.8306, 0.8305, 0.8307, 0.8309, 0.831, 0.831, 0.8312, 0.8313],
    't2': [None, 0.8087, 0.809, 0.809, 0.8095, 0.809, 0.8088, 0.8099, 0.8088, 0.8093],
    't3': [None, None, 0.7573, 0.7603, 0.7596, 0.7589, 0.759, 0.7591, 0.7604, 0.7602],
    't4': [None, None, None, 0.7506, 0.7511, 0.7518, 0.7514, 0.7522, 0.7511, 0.7526],
    't5': [None, None, None, None, 0.8489, 0.8501, 0.8509, 0.8514, 0.8511, 0.8509],
    't6': [None, None, None, None, None, 0.8082, 0.8096, 0.8093, 0.81, 0.8104],
    't7': [None, None, None, None, None, None, 0.7936, 0.7963, 0.7973, 0.7971],
    't8': [None, None, None, None, None, None, None, 0.8164, 0.8159, 0.8165],
    't9': [None, None, None, None, None, None, None, None, 0.8126, 0.8141],
    't10': [None, None, None, None, None, None, None, None, None, 0.7964]
}

# t1-t10的分类任务数据
class_data = {
    't1': [0.6927, 0.6672, 0.6519, 0.6491, 0.6323, 0.6222, 0.6103, 0.5992, 0.5862, 0.5744],
    't2': [None, 0.7184, 0.6246, 0.6149, 0.5987, 0.5566, 0.534, 0.534, 0.5275, 0.5016],
    't3': [None, None, 0.5552, 0.3754, 0.3565, 0.3407, 0.3281, 0.3343, 0.3281, 0.3155],
    't4': [None, None, None, 0.5, 0.5244, 0.503, 0.4909, 0.4817, 0.4787, 0.4665],
    't5': [None, None, None, None, 0.6261, 0.5106, 0.5106, 0.5045, 0.4985, 0.4742],
    't6': [None, None, None, None, None, 0.6552, 0.558, 0.5454, 0.4859, 0.4859],
    't7': [None, None, None, None, None, None, 0.7982, 0.6239, 0.6055, 0.5902],
    't8': [None, None, None, None, None, None, None, 0.5549, 0.4695, 0.4238],
    't9': [None, None, None, None, None, None, None, None, 0.7452, 0.672],
    't10': [None, None, None, None, None, None, None, None, None, 0.6713]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-CUB-phase_10')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-CUB-phase_10.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 3))

# t1-t2的概念任务数据
concept_data = {
    't1': [0.9778, 0.9705],
    't2': [None, 0.9574]
}

# t1-t2的分类任务数据
class_data = {
    't1': [0.9156, 0.7452],
    't2': [None, 0.9111]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-AwA-phase_2')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-AwA-phase_2.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 4))

# t1-t3的概念任务数据
concept_data = {
    't1': [0.9778, 0.9748, 0.9703],
    't2': [None, 0.9561, 0.9518],
    't3': [None, None, 0.961]
}

# t1-t3的分类任务数据
class_data = {
    't1': [0.9156, 0.8411, 0.734],
    't2': [None, 0.9225, 0.8415],
    't3': [None, None, 0.9401]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-AwA-phase_3')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-AwA-phase_3.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 5))

# t1-t4的概念任务数据
concept_data = {
    't1': [0.9777, 0.9755, 0.9737, 0.9704],
    't2': [None, 0.9633, 0.9592, 0.9561],
    't3': [None, None, 0.9629, 0.9603],
    't4': [None, None, None, 0.9545]
}

# t1-t4的分类任务数据
class_data = {
    't1': [0.9156, 0.8607, 0.8132, 0.7316],
    't2': [None, 0.9471, 0.8534, 0.8092],
    't3': [None, None, 0.9498, 0.8964],
    't4': [None, None, None, 0.9323]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-AwA-phase_4')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-AwA-phase_4.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 6))

# t1-t5的概念任务数据
concept_data = {
    't1': [0.9778, 0.9758, 0.9748, 0.9732, 0.9706],
    't2': [None, 0.9628, 0.9596, 0.9566, 0.9552],
    't3': [None, None, 0.9526, 0.9506, 0.9479],
    't4': [None, None, None, 0.9701, 0.9688],
    't5': [None, None, None, None, 0.951]
}

# t1-t5的分类任务数据
class_data = {
    't1': [0.9156, 0.8685, 0.8386, 0.8008, 0.7292],
    't2': [None, 0.9495, 0.8695, 0.8269, 0.8157],
    't3': [None, None, 0.9305, 0.8933, 0.8044],
    't4': [None, None, None, 0.9628, 0.9398],
    't5': [None, None, None, None, 0.9329]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-AwA-phase_5')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-AwA-phase_5.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 7))

# t1-t6的概念任务数据
concept_data = {
    't1': [0.9778, 0.976, 0.9753, 0.974, 0.9727, 0.9705],
    't2': [None, 0.9562, 0.9522, 0.9512, 0.9496, 0.948],
    't3': [None, None, 0.9626, 0.9604, 0.9579, 0.9566],
    't4': [None, None, None, 0.971, 0.9702, 0.9685],
    't5': [None, None, None, None, 0.9615, 0.9603],
    't6': [None, None, None, None, None, 0.9488]
}

# t1-t6的分类任务数据
class_data = {
    't1': [0.9156, 0.8736, 0.8523, 0.8072, 0.7928, 0.719],
    't2': [None, 0.9441, 0.8235, 0.81, 0.7999, 0.7758],
    't3': [None, None, 0.9504, 0.913, 0.862, 0.8232],
    't4': [None, None, None, 0.9699, 0.9417, 0.9175],
    't5': [None, None, None, None, 0.945, 0.9228],
    't6': [None, None, None, None, None, 0.9406]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-AwA-phase_6')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-AwA-phase_6.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 8))

# t1-t7的概念任务数据
concept_data = {
    't1': [0.9777, 0.9764, 0.9755, 0.9748, 0.9738, 0.9727, 0.9703],
    't2': [None, 0.9669, 0.9653, 0.9619, 0.9603, 0.9598, 0.9586],
    't3': [None, None, 0.9598, 0.9594, 0.9573, 0.9548, 0.9526],
    't4': [None, None, None, 0.9467, 0.9459, 0.9439, 0.9429],
    't5': [None, None, None, None, 0.9727, 0.9711, 0.97],
    't6': [None, None, None, None, None, 0.9643, 0.9631],
    't7': [None, None, None, None, None, None, 0.9502]
}

# t1-t7的分类任务数据
class_data = {
    't1': [0.9156, 0.8767, 0.8577, 0.8374, 0.8078, 0.7961, 0.7241],
    't2': [None, 0.9495, 0.9251, 0.8374, 0.8108, 0.8077, 0.7827],
    't3': [None, None, 0.9665, 0.9526, 0.8885, 0.863, 0.8287],
    't4': [None, None, None, 0.9258, 0.9106, 0.8721, 0.8283],
    't5': [None, None, None, None, 0.9726, 0.9452, 0.9288],
    't6': [None, None, None, None, None, 0.9534, 0.9283],
    't7': [None, None, None, None, None, None, 0.9446]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-AwA-phase_7')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-AwA-phase_7.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 9))

# t1-t8的概念任务数据
concept_data = {
    't1': [0.9777, 0.9766, 0.9756, 0.9752, 0.9744, 0.9735, 0.9723, 0.9704],
    't2': [None, 0.9721, 0.9676, 0.9637, 0.9631, 0.9622, 0.9625, 0.9614],
    't3': [None, None, 0.9587, 0.9572, 0.9556, 0.9529, 0.9518, 0.9503],
    't4': [None, None, None, 0.9361, 0.9361, 0.9327, 0.9291, 0.9286],
    't5': [None, None, None, None, 0.9785, 0.9778, 0.9772, 0.9765],
    't6': [None, None, None, None, None, 0.952, 0.9504, 0.9492],
    't7': [None, None, None, None, None, None, 0.967, 0.9657],
    't8': [None, None, None, None, None, None, None, 0.9448]
}

# t1-t8的分类任务数据
class_data = {
    't1': [0.9156, 0.8823, 0.8629, 0.8587, 0.8383, 0.8025, 0.7856, 0.7256],
    't2': [None, 0.9731, 0.8244, 0.7025, 0.7085, 0.6936, 0.7003, 0.6749],
    't3': [None, None, 0.973, 0.9485, 0.9173, 0.8854, 0.8627, 0.8523],
    't4': [None, None, None, 0.8887, 0.847, 0.8261, 0.6922, 0.6626],
    't5': [None, None, None, None, 0.9849, 0.9697, 0.9648, 0.9405],
    't6': [None, None, None, None, None, 0.9353, 0.881, 0.8586],
    't7': [None, None, None, None, None, None, 0.9504, 0.9297],
    't8': [None, None, None, None, None, None, None, 0.9469]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')

# 设置图例和标签
plt.title('CONCIL-AwA-phase_8')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-AwA-phase_8.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 10))

# t1-t9的概念任务数据
concept_data = {
    't1': [0.9777, 0.9766, 0.9759, 0.9754, 0.9748, 0.9739, 0.9731, 0.9723, 0.9705],
    't2': [None, 0.9721, 0.9681, 0.9645, 0.9633, 0.962, 0.9616, 0.9616, 0.9605],
    't3': [None, None, 0.9582, 0.9571, 0.9562, 0.9545, 0.9525, 0.9513, 0.9502],
    't4': [None, None, None, 0.9438, 0.9441, 0.9431, 0.9411, 0.9378, 0.9369],
    't5': [None, None, None, None, 0.9597, 0.9587, 0.9585, 0.9579, 0.9569],
    't6': [None, None, None, None, None, 0.975, 0.9739, 0.9734, 0.9725],
    't7': [None, None, None, None, None, None, 0.9653, 0.9646, 0.9638],
    't8': [None, None, None, None, None, None, None, 0.9612, 0.9599],
    't9': [None, None, None, None, None, None, None, None, 0.946]
}

# t1-t9的分类任务数据
class_data = {
    't1': [0.9156, 0.8823, 0.8651, 0.8587, 0.8381, 0.8113, 0.7986, 0.7848, 0.7283],
    't2': [None, 0.9731, 0.8019, 0.7138, 0.716, 0.7167, 0.7115, 0.719, 0.6966],
    't3': [None, None, 0.9806, 0.9484, 0.9476, 0.9162, 0.8893, 0.8878, 0.8788],
    't4': [None, None, None, 0.9169, 0.8951, 0.8856, 0.8474, 0.7493, 0.7384],
    't5': [None, None, None, None, 0.9533, 0.9315, 0.9273, 0.9128, 0.865],
    't6': [None, None, None, None, None, 0.977, 0.9457, 0.9398, 0.9244],
    't7': [None, None, None, None, None, None, 0.9594, 0.9475, 0.9281],
    't8': [None, None, None, None, None, None, None, 0.9395, 0.9087],
    't9': [None, None, None, None, None, None, None, None, 0.9469]
}

# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')


# # Full-concept 和 Full-class 数据
# full_concept_data = [0.9777, 0.9774, 0.9723, 0.972, 0.9689, 0.9701, 0.9684, 0.9669, 0.9656, 0.9636]
# full_class_data = [0.9256, 0.9124, 0.8742, 0.8701, 0.8503, 0.8523, 0.8395, 0.8327, 0.8202, 0.7969]
# # 绘制 Full-concept 和 Full-class 曲线
# plt.plot(phases, full_concept_data, marker='s', linestyle='-', label='Full-concept', linewidth=2, markersize=7, color='red')
# plt.plot(phases, full_class_data, marker='d', linestyle='-', label='Full-class', linewidth=2, markersize=7, color='blue')

# 设置图例和标签
plt.title('CONCIL-AwA-phase_9')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-AwA-phase_9.png', dpi=300)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
phases = list(range(1, 11))

# t1-t10的概念任务数据
concept_data = {
    't1': [0.9777, 0.9773, 0.976, 0.9754, 0.975, 0.9748, 0.9739, 0.9732, 0.9722, 0.9707],
    't2': [None, 0.9782, 0.9722, 0.971, 0.9661, 0.966, 0.9655, 0.9652, 0.9653, 0.9647],
    't3': [None, None, 0.9428, 0.9404, 0.9392, 0.939, 0.9368, 0.9351, 0.934, 0.9324],
    't4': [None, None, None, 0.9749, 0.975, 0.9738, 0.9732, 0.9719, 0.9705, 0.9699],
    't5': [None, None, None, None, 0.9293, 0.929, 0.9289, 0.9262, 0.9264, 0.9246],
    't6': [None, None, None, None, None, 0.9884, 0.988, 0.9877, 0.9877, 0.9876],
    't7': [None, None, None, None, None, None, 0.961, 0.9597, 0.9589, 0.9579],
    't8': [None, None, None, None, None, None, None, 0.9576, 0.9574, 0.9574],
    't9': [None, None, None, None, None, None, None, None, 0.9575, 0.9548],
    't10': [None, None, None, None, None, None, None, None, None, 0.954]
}

# t1-t10的分类任务数据
class_data = {
    't1': [0.9256, 0.9042, 0.8731, 0.8568, 0.8463, 0.8364, 0.8061, 0.7985, 0.7727, 0.7228],
    't2': [None, 0.9859, 0.7889, 0.797, 0.6484, 0.6586, 0.6505, 0.6495, 0.6535, 0.6303],
    't3': [None, None, 0.9613, 0.9345, 0.8994, 0.9031, 0.8856, 0.8727, 0.8589, 0.8404],
    't4': [None, None, None, 0.9729, 0.9644, 0.9364, 0.9127, 0.9034, 0.85, 0.8559],
    't5': [None, None, None, None, 0.9209, 0.9179, 0.9045, 0.8493, 0.8328, 0.7881],
    't6': [None, None, None, None, None, 0.9826, 0.97, 0.9642, 0.9632, 0.9274],
    't7': [None, None, None, None, None, None, 0.9586, 0.9087, 0.8933, 0.8792],
    't8': [None, None, None, None, None, None, None, 0.9396, 0.9271, 0.9],
    't9': [None, None, None, None, None, None, None, None, 0.9593, 0.9242],
    't10': [None, None, None, None, None, None, None, None, None, 0.9585]
}




# 绘制概念任务曲线
plt.figure(figsize=(12, 8))
for task, data in concept_data.items():
    plt.plot(phases, data, marker='o', label=f'{task}-concept')

# 绘制分类任务曲线
for task, data in class_data.items():
    plt.plot(phases, data, marker='x', linestyle='--', label=f'{task}-class')


# # Full-concept 和 Full-class 数据
# full_concept_data = [0.9777, 0.9774, 0.9723, 0.972, 0.9689, 0.9701, 0.9684, 0.9669, 0.9656, 0.9636]
# full_class_data = [0.9256, 0.9124, 0.8742, 0.8701, 0.8503, 0.8523, 0.8395, 0.8327, 0.8202, 0.7969]
# # 绘制 Full-concept 和 Full-class 曲线
# plt.plot(phases, full_concept_data, marker='s', linestyle='-', label='Full-concept', linewidth=2, markersize=7, color='red')
# plt.plot(phases, full_class_data, marker='d', linestyle='-', label='Full-class', linewidth=2, markersize=7, color='blue')

# 设置图例和标签
plt.title('CONCIL-AwA-phase_10')
plt.xlabel('Phase')
plt.ylabel('Performance')
plt.legend()
plt.grid(True)
plt.xticks(phases)

# 固定纵坐标区间为 [0, 1]
plt.ylim(0, 1)

# 保存图表为 PNG 文件
plt.savefig('CONCIL-AwA-phase_10.png', dpi=300)

# 显示图形
plt.show()
