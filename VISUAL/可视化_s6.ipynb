# %%
import matplotlib.pyplot as plt

# 数据
stages = list(range(1, 10))
baseline_concept = [0.7357, 0.7286, 0.7046, 0.693, 0.676, 0.6638, 0.6647, 0.6502, 0.6502]
concil_concept = [0.8233, 0.822, 0.82, 0.8207, 0.8205, 0.8202, 0.8203, 0.8204, 0.8204]

baseline_class = [0.6119, 0.4297, 0.3305, 0.2692, 0.2263, 0.195, 0.1723, 0.1513, 0.1513]
concil_class = [0.6287, 0.6216, 0.6163, 0.6064, 0.609, 0.6118, 0.6079, 0.6043, 0.6043]

# 创建图表
plt.figure(figsize=(12, 6))

# Full Concept Accuracy
plt.subplot(1, 2, 1)
plt.plot(stages, baseline_concept, marker='o', label='Baseline')
plt.plot(stages, concil_concept, marker='o', label='CONCIL')
plt.title('Full Concept Accuracy')
plt.xlabel('Stage')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Full Class Accuracy
plt.subplot(1, 2, 2)
plt.plot(stages, baseline_class, marker='o', label='Baseline')
plt.plot(stages, concil_class, marker='o', label='CONCIL')
plt.title('Full Class Accuracy')
plt.xlabel('Stage')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据集CUB
stages = list(range(1, 10))
baseline_concept_cub = [0.7357, 0.7286, 0.7046, 0.693, 0.676, 0.6638, 0.6647, 0.6502, 0.6502]
concil_concept_cub = [0.8233, 0.822, 0.82, 0.8207, 0.8205, 0.8202, 0.8203, 0.8204, 0.8204]

baseline_class_cub = [0.6119, 0.4297, 0.3305, 0.2692, 0.2263, 0.195, 0.1723, 0.1513, 0.1513]
concil_class_cub = [0.6287, 0.6216, 0.6163, 0.6064, 0.609, 0.6118, 0.6079, 0.6043, 0.6043]

# 数据集AwA
baseline_concept_awa = [0.9262, 0.8709, 0.8364, 0.8095, 0.7866, 0.7747, 0.7592, 0.7488, 0.7488]
concil_concept_awa = [0.9708, 0.9699, 0.9704, 0.9701, 0.9699, 0.9703, 0.9704, 0.9702, 0.9702]

baseline_class_awa = [0.7601, 0.5036, 0.3888, 0.3149, 0.2644, 0.2283, 0.201, 0.1794, 0.1794]
concil_class_awa = [0.8739, 0.8675, 0.8647, 0.8624, 0.858, 0.8616, 0.8561, 0.855, 0.855]

# 创建图表
plt.figure(figsize=(18, 6))

# Full Concept Accuracy
plt.subplot(1, 2, 1)
plt.plot(stages, baseline_concept_cub, marker='o', label='Baseline (CUB)')
plt.plot(stages, concil_concept_cub, marker='o', label='CONCIL (CUB)')
plt.plot(stages, baseline_concept_awa, marker='x', label='Baseline (AwA)')
plt.plot(stages, concil_concept_awa, marker='x', label='CONCIL (AwA)')
plt.title('Full Concept Accuracy')
plt.xlabel('Stage')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Full Class Accuracy
plt.subplot(1, 2, 2)
plt.plot(stages, baseline_class_cub, marker='o', label='Baseline (CUB)')
plt.plot(stages, concil_class_cub, marker='o', label='CONCIL (CUB)')
plt.plot(stages, baseline_class_awa, marker='x', label='Baseline (AwA)')
plt.plot(stages, concil_class_awa, marker='x', label='CONCIL (AwA)')
plt.title('Full Class Accuracy')
plt.xlabel('Stage')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据集CUB
stages = list(range(1, 10))
baseline_concept_cub = [None, 0.7357, 0.7286, 0.7046, 0.693, 0.676, 0.6638, 0.6647, 0.6502]
concil_concept_cub = [None, 0.8233, 0.822, 0.82, 0.8207, 0.8205, 0.8202, 0.8203, 0.8204]

baseline_class_cub = [None, 0.6119, 0.4297, 0.3305, 0.2692, 0.2263, 0.195, 0.1723, 0.1513]
concil_class_cub = [None, 0.6287, 0.6216, 0.6163, 0.6064, 0.609, 0.6118, 0.6079, 0.6043]

# 数据集AwA
baseline_concept_awa = [None, 0.9262, 0.8709, 0.8364, 0.8095, 0.7866, 0.7747, 0.7592, 0.7488]
concil_concept_awa = [None, 0.9708, 0.9699, 0.9704, 0.9701, 0.9699, 0.9703, 0.9704, 0.9702]

baseline_class_awa = [None, 0.7601, 0.5036, 0.3888, 0.3149, 0.2644, 0.2283, 0.201, 0.1794]
concil_class_awa = [None, 0.8739, 0.8675, 0.8647, 0.8624, 0.858, 0.8616, 0.8561, 0.855]

# 创建图表
plt.figure(figsize=(12, 6))

# Full Concept Accuracy
plt.plot(stages, baseline_concept_cub, marker='o', linestyle='-', color='#1f77b4', label='Baseline (CUB) - Concept')
plt.plot(stages, concil_concept_cub, marker='s', linestyle='--', color='#ff7f0e', label='CONCIL (CUB) - Concept')
plt.plot(stages, baseline_concept_awa, marker='^', linestyle='-', color='#1f77b4', label='Baseline (AwA) - Concept')
plt.plot(stages, concil_concept_awa, marker='v', linestyle='--', color='#ff7f0e', label='CONCIL (AwA) - Concept')

# Full Class Accuracy
plt.plot(stages, baseline_class_cub, marker='o', linestyle='-', color='#2ca02c', label='Baseline (CUB) - Class')
plt.plot(stages, concil_class_cub, marker='s', linestyle='--', color='#d62728', label='CONCIL (CUB) - Class')
plt.plot(stages, baseline_class_awa, marker='^', linestyle='-', color='#2ca02c', label='Baseline (AwA) - Class')
plt.plot(stages, concil_class_awa, marker='v', linestyle='--', color='#d62728', label='CONCIL (AwA) - Class')

plt.title('Full Concept and Class Accuracy for CUB and AwA Datasets')
plt.xlabel('Phase')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.legend()
plt.grid(True)

plt.tight_layout()
# 保存图表为 PNG 文件
plt.savefig('Acc_all.png', dpi=300)

plt.show()
